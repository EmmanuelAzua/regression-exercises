# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import env
import acquire
from env import username, password, host
from acquire import telco_churn_data
from acquire import churn_data_csv

# %%
telco_churn_data()
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   1                         1                 2  2794-XIMMO
# 1                   1                         1                 2  2851-STERV
# 2                   1                         1                 2  2898-LSJGD
# 3                   1                         1                 2  2969-WGHQO
# 4                   1                         1                 2  2988-PLAHS
# ...               ...                       ...               ...         ...
# 7038                3                         3                 3  9178-JHUVJ
# 7039                3                         3                 3  9257-AZMTZ
# 7040                3                         3                 3  9537-JALFH
# 7041                3                         3                 3  9574-BOSMD
# 7042                3                         3                 3  9764-REAFF
#
# ...

# %%
churn_data_csv()
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 3  0016-QLJIS
# 1                   4                         1                 3  0017-DINOC
# 2                   3                         1                 3  0019-GFNTW
# 3                   4                         1                 3  0056-EPFBG
# 4                   3                         1                 3  0078-XZMHT
# ...               ...                       ...               ...         ...
# 7038                2                         3                 1  9962-BFPDU
# 7039                2                         3                 1  9967-ATRFS
# 7040                4                         3                 1  9970-QBCDA
# 7041                2                         3                 1  9975-SKRNR
# 7042                3                         3                 1  9986-BONCE
#
# ...

# %%
telco_df = churn_data_csv()

# %%
telco_df.columns
# Out:
# Index(['payment_type_id', 'internet_service_type_id', 'contract_type_id',
#        'customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'online_security',
#        'online_backup', 'device_protection', 'tech_support', 'streaming_tv',
#        'streaming_movies', 'paperless_billing', 'monthly_charges',
#        'total_charges', 'churn', 'contract_type', 'internet_service_type',
#        'payment_type'],
#       dtype='object')

# %%
telco_df = telco_df[['customer_id', 'monthly_charges', 'tenure', 'total_charges', 'contract_type', 'contract_type_id']]
telco_df
# Out:
#      customer_id  monthly_charges  tenure total_charges   contract_type  \
# 0     0016-QLJIS            90.45      65        5957.9        Two year
# 1     0017-DINOC            45.20      54       2460.55        Two year
# 2     0019-GFNTW            45.05      56        2560.1        Two year
# 3     0056-EPFBG            39.40      20         825.4        Two year
# 4     0078-XZMHT            85.15      72        6316.2        Two year
# ...          ...              ...     ...           ...             ...
# 7038  9962-BFPDU            20.05       1         20.05  Month-to-month
# 7039  9967-ATRFS            19.90      19        367.55  Month-to-month
# 7040  9970-QBCDA            19.70       6        129.55  Month-to-month
# 7041  9975-SKRNR            18.90       1          18.9  Month-to-month
# 7042  9986-BONCE            20.95       4          85.5  Month-to-month
#
#       contract_type_id
# 0                    3
# 1                    3
# 2                    3
# ...

# %%
telco_df = telco_df[telco_df.contract_type == "Two year"]
telco_df
# Out:
#      customer_id  monthly_charges  tenure total_charges contract_type  \
# 0     0016-QLJIS            90.45      65        5957.9      Two year
# 1     0017-DINOC            45.20      54       2460.55      Two year
# 2     0019-GFNTW            45.05      56        2560.1      Two year
# 3     0056-EPFBG            39.40      20         825.4      Two year
# 4     0078-XZMHT            85.15      72        6316.2      Two year
# ...          ...              ...     ...           ...           ...
# 6150  9950-MTGYX            20.30      28        487.95      Two year
# 6151  9953-ZMKSM            25.25      63        1559.3      Two year
# 6152  9964-WBQDJ            24.40      71        1725.4      Two year
# 6153  9972-EWRJS            19.25      67        1372.9      Two year
# 6154  9975-GPKZU            19.75      46         856.5      Two year
#
#       contract_type_id
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# ...

# %%
telco_df[telco_df.isna().any(axis=1)].count()
# Out:
# customer_id         0
# monthly_charges     0
# tenure              0
# total_charges       0
# contract_type       0
# contract_type_id    0
# dtype: int64

# %%
telco_df[telco_df.tenure == 1]
# Out:
#      customer_id  monthly_charges  tenure total_charges contract_type  \
# 5587  1099-GODLO            20.35       1         20.35      Two year
# 6067  8559-WNQZS            20.45       1         20.45      Two year
#
#       contract_type_id
# 5587                 3
# 6067                 3

# %%
telco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1695 entries, 0 to 6154
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1695 non-null   object
#  1   monthly_charges   1695 non-null   float64
#  2   tenure            1695 non-null   int64
#  3   total_charges     1695 non-null   object
#  4   contract_type     1695 non-null   object
#  5   contract_type_id  1695 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 92.7+ KB

# %%
telco_df = telco_df[['customer_id', 'monthly_charges', 'tenure', 'total_charges']]
telco_df
# Out:
#      customer_id  monthly_charges  tenure total_charges
# 0     0016-QLJIS            90.45      65        5957.9
# 1     0017-DINOC            45.20      54       2460.55
# 2     0019-GFNTW            45.05      56        2560.1
# 3     0056-EPFBG            39.40      20         825.4
# 4     0078-XZMHT            85.15      72        6316.2
# ...          ...              ...     ...           ...
# 6150  9950-MTGYX            20.30      28        487.95
# 6151  9953-ZMKSM            25.25      63        1559.3
# 6152  9964-WBQDJ            24.40      71        1725.4
# 6153  9972-EWRJS            19.25      67        1372.9
# 6154  9975-GPKZU            19.75      46         856.5
#
# [1695 rows x 4 columns]
